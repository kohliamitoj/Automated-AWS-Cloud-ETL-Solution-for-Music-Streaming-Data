# %%
# !pip install spotipy
# Out:
# ...
#   Obtaining dependency information for redis>=3.5.3 from https://files.pythonhosted.org/packages/0b/34/a01250ac1fc9bf9161e07956d2d580413106ce02d5591470130a25c599e3/redis-5.0.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for async-timeout>=4.0.2 from https://files.pythonhosted.org/packages/a7/fa/e01228c2938de91d47b307831c62ab9e4001e747789d0b05baf779a6488c/async_timeout-4.0.3-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.3/250.3 kB 6.0 MB/s eta 0:00:0000:01
# ...
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 4.0.1
#     Uninstalling async-timeout-4.0.1:
#       Successfully uninstalled async-timeout-4.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# s3fs 2023.6.0 requires fsspec==2023.6.0, but you have fsspec 2022.2.0 which is incompatible.
# ...
#
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id = "af3446b055cb42fb8f6f39f3aec100d8", 
                                                      client_secret = "4de264f21f284ed69ce0e7ef6a4f7763")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF"

# %%
playlist_URI = playlist_link.split("/")

# %%
playlist_URI
# Out:
# ['https:', '', 'open.spotify.com', 'playlist', '37i9dQZEVXbNG2KDcFcKOF']

# %%
playlist_URI = playlist_link.split("/")[-1]
playlist_URI
# Out:
# '37i9dQZEVXbNG2KDcFcKOF'

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbNG2KDcFcKOF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-02-09T10:19:04Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Me35AWHCGqW4sZ7bWWJt1'},
#        'href': 'https://api.spotify.com/v1/artists/3Me35AWHCGqW4sZ7bWWJt1',
#        'id': '3Me35AWHCGqW4sZ7bWWJt1',
#        'name': 'Xavi',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Me35AWHCGqW4sZ7bWWJt1'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
# ...

# %%
data['items']
# Out:
# [{'added_at': '2024-02-09T10:19:04Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Me35AWHCGqW4sZ7bWWJt1'},
#       'href': 'https://api.spotify.com/v1/artists/3Me35AWHCGqW4sZ7bWWJt1',
#       'id': '3Me35AWHCGqW4sZ7bWWJt1',
#       'name': 'Xavi',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Me35AWHCGqW4sZ7bWWJt1'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2024-02-09T10:19:04Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Me35AWHCGqW4sZ7bWWJt1'},
#      'href': 'https://api.spotify.com/v1/artists/3Me35AWHCGqW4sZ7bWWJt1',
#      'id': '3Me35AWHCGqW4sZ7bWWJt1',
#      'name': 'Xavi',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Me35AWHCGqW4sZ7bWWJt1'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
# ...

# %%
len(data['items'])
# Out:
# 50

# %%
data['items'][0]['track']
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Me35AWHCGqW4sZ7bWWJt1'},
#     'href': 'https://api.spotify.com/v1/artists/3Me35AWHCGqW4sZ7bWWJt1',
#     'id': '3Me35AWHCGqW4sZ7bWWJt1',
#     'name': 'Xavi',
#     'type': 'artist',
#     'uri': 'spotify:artist:3Me35AWHCGqW4sZ7bWWJt1'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
# ...

# %%
data['items'][0]['track']['album']
# Out:
# {'album_type': 'single',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Me35AWHCGqW4sZ7bWWJt1'},
#    'href': 'https://api.spotify.com/v1/artists/3Me35AWHCGqW4sZ7bWWJt1',
#    'id': '3Me35AWHCGqW4sZ7bWWJt1',
#    'name': 'Xavi',
#    'type': 'artist',
#    'uri': 'spotify:artist:3Me35AWHCGqW4sZ7bWWJt1'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
# ...

# %%
data['items'][0]['track']['album']['album_type']
# Out:
# 'single'

# %%
data['items'][0]['track']['album']['id']
# Out:
# '2IoSjweCu07y9mv5H1Cj3v'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'La Diabla'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-11-30'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/2IoSjweCu07y9mv5H1Cj3v'

# %%
# to extract album info for all other albums available in the list

album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_type = row['track']['album']['album_type']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,
                     'name':album_name,
                     'album_type':album_type,
                     'release_date':album_release_date,
                     'total_tracks':album_total_tracks,
                     'url':album_url}
    album_list.append(album_element)

# %%
# more structured data
album_list
# Out:
# [{'album_id': '2IoSjweCu07y9mv5H1Cj3v',
#   'name': 'La Diabla',
#   'album_type': 'single',
#   'release_date': '2023-11-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2IoSjweCu07y9mv5H1Cj3v'},
#  {'album_id': '3UOV8XvCwMKaATRNXrYCjN',
#   'name': 'greedy',
#   'album_type': 'single',
#   'release_date': '2023-09-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3UOV8XvCwMKaATRNXrYCjN'},
#  {'album_id': '29aSKB1qPEbN0Qf9OPSQpw',
#   'name': 'Beautiful Things',
#   'album_type': 'single',
#   'release_date': '2024-01-18',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/29aSKB1qPEbN0Qf9OPSQpw'},
#  {'album_id': '7tzVd1fwkxsorytCBjEJkU',
#   'name': 'The Idol Episode 4 (Music from the HBO Original Series)',
#   'album_type': 'single',
#   'release_date': '2023-06-23',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/7tzVd1fwkxsorytCBjEJkU'},
#  {'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'name': 'Lover',
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2024-02-09T10:19:04Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Me35AWHCGqW4sZ7bWWJt1'},
#      'href': 'https://api.spotify.com/v1/artists/3Me35AWHCGqW4sZ7bWWJt1',
#      'id': '3Me35AWHCGqW4sZ7bWWJt1',
#      'name': 'Xavi',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Me35AWHCGqW4sZ7bWWJt1'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
# ...

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Me35AWHCGqW4sZ7bWWJt1'},
#   'href': 'https://api.spotify.com/v1/artists/3Me35AWHCGqW4sZ7bWWJt1',
#   'id': '3Me35AWHCGqW4sZ7bWWJt1',
#   'name': 'Xavi',
#   'type': 'artist',
#   'uri': 'spotify:artist:3Me35AWHCGqW4sZ7bWWJt1'}]

# %%
data['items'][0]['track']['artists'][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Me35AWHCGqW4sZ7bWWJt1'},
#  'href': 'https://api.spotify.com/v1/artists/3Me35AWHCGqW4sZ7bWWJt1',
#  'id': '3Me35AWHCGqW4sZ7bWWJt1',
#  'name': 'Xavi',
#  'type': 'artist',
#  'uri': 'spotify:artist:3Me35AWHCGqW4sZ7bWWJt1'}

# %%
data['items'][0]['track']['artists'][0]['type']
# Out:
# 'artist'

# %%
data['items'][0]['track']['artists'][0]['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/artist/3Me35AWHCGqW4sZ7bWWJt1'

# %%
# to extract artist info for all other tracks available in the list

artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 
                               'artist_name':artist['name'],
                               'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '3Me35AWHCGqW4sZ7bWWJt1',
#   'artist_name': 'Xavi',
#   'external_url': 'https://api.spotify.com/v1/artists/3Me35AWHCGqW4sZ7bWWJt1'},
#  {'artist_id': '45dkTj5sMRSjrmBSBeiHym',
#   'artist_name': 'Tate McRae',
#   'external_url': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym'},
#  {'artist_id': '22wbnEMDvgVIAGdFeek6ET',
#   'artist_name': 'Benson Boone',
#   'external_url': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '250b0Wlc5Vk0CoUsaCY84M',
#   'artist_name': 'JENNIE',
#   'external_url': 'https://api.spotify.com/v1/artists/250b0Wlc5Vk0CoUsaCY84M'},
#  {'artist_id': '1pBLC0qVRTB5zVMuteQ9jJ',
#   'artist_name': 'Lily-Rose Depp',
#   'external_url': 'https://api.spotify.com/v1/artists/1pBLC0qVRTB5zVMuteQ9jJ'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2024-02-09T10:19:04Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Me35AWHCGqW4sZ7bWWJt1'},
#      'href': 'https://api.spotify.com/v1/artists/3Me35AWHCGqW4sZ7bWWJt1',
#      'id': '3Me35AWHCGqW4sZ7bWWJt1',
#      'name': 'Xavi',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Me35AWHCGqW4sZ7bWWJt1'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
# ...

# %%
data['items'][0]['track']['duration_ms']
# Out:
# 172264

# %%
data['items'][0]['track']['name']
# Out:
# 'La Diabla'

# %%
# to extract song info for all other tracks available in the list

song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    
    song_element = {'song_id':song_id,
                    'song_name':song_name,
                    'duration_ms':song_duration,
                    'url':song_url,
                    'popularity':song_popularity,
                    'song_added':song_added,
                    'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '0R6NfOiLzLj4O5VbYSJAjf',
#   'song_name': 'La Diabla',
#   'duration_ms': 172264,
#   'url': 'https://open.spotify.com/track/0R6NfOiLzLj4O5VbYSJAjf',
#   'popularity': 99,
#   'song_added': '2024-02-09T10:19:04Z',
#   'album_id': '2IoSjweCu07y9mv5H1Cj3v',
#   'artist_id': '3Me35AWHCGqW4sZ7bWWJt1'},
#  {'song_id': '3rUGC1vUpkDG9CZFHMur1t',
#   'song_name': 'greedy',
#   'duration_ms': 131872,
#   'url': 'https://open.spotify.com/track/3rUGC1vUpkDG9CZFHMur1t',
#   'popularity': 100,
#   'song_added': '2024-02-09T10:19:04Z',
#   'album_id': '3UOV8XvCwMKaATRNXrYCjN',
#   'artist_id': '45dkTj5sMRSjrmBSBeiHym'},
#  {'song_id': '6tNQ70jh4OwmPGpYy6R2o9',
#   'song_name': 'Beautiful Things',
#   'duration_ms': 180304,
#   'url': 'https://open.spotify.com/track/6tNQ70jh4OwmPGpYy6R2o9',
#   'popularity': 96,
#   'song_added': '2024-02-09T10:19:04Z',
#   'album_id': '29aSKB1qPEbN0Qf9OPSQpw',
#   'artist_id': '22wbnEMDvgVIAGdFeek6ET'},
#  {'song_id': '7CyPwkp0oE8Ro9Dd5CUDjW',
# ...

# %%
# album df

album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                                               name  \
# 0  2IoSjweCu07y9mv5H1Cj3v                                          La Diabla
# 1  3UOV8XvCwMKaATRNXrYCjN                                             greedy
# 2  29aSKB1qPEbN0Qf9OPSQpw                                   Beautiful Things
# 3  7tzVd1fwkxsorytCBjEJkU  The Idol Episode 4 (Music from the HBO Origina...
# 4  1NAmidJlEaVgA3MpcPFYGq                                              Lover
#
#   album_type release_date  total_tracks  \
# 0     single   2023-11-30             1
# 1     single   2023-09-15             1
# 2     single   2024-01-18             1
# 3     single   2023-06-23             3
# 4      album   2019-08-23            18
#
#                                                  url
# 0  https://open.spotify.com/album/2IoSjweCu07y9mv...
# 1  https://open.spotify.com/album/3UOV8XvCwMKaATR...
# 2  https://open.spotify.com/album/29aSKB1qPEbN0Qf...
# ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   album_type    50 non-null     object
#  3   release_date  50 non-null     object
#  4   total_tracks  50 non-null     int64
#  5   url           50 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 2.5+ KB

# %%
number_of_duplicates_album = album_df.duplicated(subset=['album_id']).sum()

print(f"Number of duplicate rows based on 'album_id': {number_of_duplicates}")
# Out:
# Number of duplicate rows based on 'album_id': 1

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
number_of_duplicates_album = album_df.duplicated(subset=['album_id']).sum()

print(f"Number of duplicate rows based on 'album_id': {number_of_duplicates}")
# Out:
# Number of duplicate rows based on 'album_id': 0

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      49 non-null     object
#  1   name          49 non-null     object
#  2   album_type    49 non-null     object
#  3   release_date  49 non-null     datetime64[ns]
#  4   total_tracks  49 non-null     int64
#  5   url           49 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 2.7+ KB

# %%
# artist df

artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
# Out:
#                 artist_id   artist_name  \
# 0  3Me35AWHCGqW4sZ7bWWJt1          Xavi
# 1  45dkTj5sMRSjrmBSBeiHym    Tate McRae
# 2  22wbnEMDvgVIAGdFeek6ET  Benson Boone
# 3  1Xyo4u8uXC1ZmMpatF05PJ    The Weeknd
# 4  250b0Wlc5Vk0CoUsaCY84M        JENNIE
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/3Me35AWHCGq...
# 1  https://api.spotify.com/v1/artists/45dkTj5sMRS...
# 2  https://api.spotify.com/v1/artists/22wbnEMDvgV...
# 3  https://api.spotify.com/v1/artists/1Xyo4u8uXC1...
# 4  https://api.spotify.com/v1/artists/250b0Wlc5Vk...

# %%
number_of_duplicates_artist = artist_df.duplicated(subset=['artist_id']).sum()

print(f"Number of duplicate rows based on 'artist_id': {number_of_duplicates}")
# Out:
# Number of duplicate rows based on 'album_id': 0

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
#Song Dataframe

song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id                                       song_name  \
# 0  0R6NfOiLzLj4O5VbYSJAjf                                       La Diabla
# 1  3rUGC1vUpkDG9CZFHMur1t                                          greedy
# 2  6tNQ70jh4OwmPGpYy6R2o9                                Beautiful Things
# 3  7CyPwkp0oE8Ro9Dd5CUDjW  One Of The Girls (with JENNIE, Lily Rose Depp)
# 4  1BxfuPKGuaTgP7aM0Bbdwr                                    Cruel Summer
#
#    duration_ms                                                url  popularity  \
# 0       172264  https://open.spotify.com/track/0R6NfOiLzLj4O5V...          99
# 1       131872  https://open.spotify.com/track/3rUGC1vUpkDG9CZ...         100
# 2       180304  https://open.spotify.com/track/6tNQ70jh4OwmPGp...          96
# 3       244684  https://open.spotify.com/track/7CyPwkp0oE8Ro9D...          98
# 4       178426  https://open.spotify.com/track/1BxfuPKGuaTgP7a...          99
#
# ...

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB
